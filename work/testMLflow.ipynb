# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA RTX A5000 Laptop GPU

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /opt/conda/bin/python
# 3.11.10 | packaged by conda-forge | (main, Sep 30 2024, 18:08:57) [GCC 13.3.0]

# %%
# %pip install -U "typing_extensions>=4.15.0"
# %pip install -U "mlflow>=2.22,<2.23"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mlflow
import importlib.metadata

print("MLflow:", mlflow.__version__)
print("typing_extensions:", importlib.metadata.version("typing_extensions"))
# Out:
# MLflow: 2.22.5
# typing_extensions: 4.15.0

# %%
import mlflow

mlflow.set_tracking_uri("http://mlflow-server.kubeflow.svc.cluster.local:5000")

with mlflow.start_run():
    mlflow.log_param("gpu", "RTX A5000")
    mlflow.log_metric("test_metric", 1.0)

print("MLflow test OK")
# Out:
# 🏃 View run delicate-snake-614 at: http://mlflow-server.kubeflow.svc.cluster.local:5000/#/experiments/0/runs/59617db591ad4e37b24581382c3d1c1a
# 🧪 View experiment at: http://mlflow-server.kubeflow.svc.cluster.local:5000/#/experiments/0
# MLflow test OK
