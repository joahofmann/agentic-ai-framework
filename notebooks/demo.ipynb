# %%
import sys
sys.path.insert(0, "/home/jovyan/agentic-ai-framework")

from agentic.agents import run_demo_agent

result = run_demo_agent()
# Out:
# PyTorch is currently using: CUDA
# GPU name: NVIDIA RTX A5000 Laptop GPU
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Question:
# What does the stable MLOps stack run on?
#
# Retrieved Context:
#
#         The current system is a stable MLOps stack.
#         It runs on WSL2 with MicroK8s and Charmed Kubeflow 1.10.
#         MLflow is integrated.
#         GPU acceleration works in notebooks.
#         GPU acceleration works in pipeline pods via Kyverno.
#         Ollama runs inside Ubuntu and is reachable through a Kubernetes Service.
#
#
# Answer:
# WSL2 with MicroK8s and Charmed Kubeflow 1.10.
